# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('c:/users/rahul/work/Sports celebrity classification/Model/dataset/virat/virat (129).jpg')
img.shape
# Out:
# (1038, 1600, 3)

# %%
# the shape is 3D, first two are x and y, the third one shows RGB channel
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1038, 1600)

# %%
gray
# Out:
# array([[43, 43, 43, ..., 52, 52, 52],
#        [43, 43, 43, ..., 52, 52, 52],
#        [44, 44, 44, ..., 52, 51, 51],
#        ...,
#        [19, 19, 19, ..., 23, 23, 23],
#        [19, 19, 19, ..., 23, 23, 23],
#        [19, 19, 19, ..., 23, 23, 23]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
# openCV has harcascade which trained programs to detect eye, nose etc on face 
face_cascade = cv2.CascadeClassifier('C:/Users/Rahul/work/opencv/sources/data/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:/Users/Rahul/work/opencv/sources/data/haarcascades/haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[670, 285, 671, 671]])

# %%
# this array has dimension x, y,width, height
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (670, 285, 671, 671)

# %%
face_img = cv2.rectangle(img, (x,y),(x+w, y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for(x,y,w,h) in faces:
    face_img = cv2.rectangle(img, (x,y),(x+w, y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        
plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (671, 671, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('c:/users/rahul/work/Sports celebrity classification/Model/dataset/Dhoni/dhoni (1).jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('c:/users/rahul/work/Sports celebrity classification/Model/dataset/Dhoni/dhoni (1).jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "c:/users/rahul/work/Sports celebrity classification/Model/dataset/"
path_to_cr_data = "c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped',
#  'c:/users/rahul/work/Sports celebrity classification/Model/dataset/Dhoni',
#  'c:/users/rahul/work/Sports celebrity classification/Model/dataset/PV_Sindhu',
#  'c:/users/rahul/work/Sports celebrity classification/Model/dataset/virat']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# Dhoni
# Generating cropped images in folder:  c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni
# PV_Sindhu
# Generating cropped images in folder:  c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu
# virat
# Generating cropped images in folder:  c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Dhoni': ['c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni1.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni10.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni11.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni12.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni13.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni14.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni15.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni16.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni17.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni18.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni19.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni2.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni20.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni21.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni22.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni23.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni24.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni25.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni26.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni27.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni28.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni29.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni3.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni30.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni31.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni32.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni33.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni34.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni35.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni36.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni37.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni38.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni39.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni4.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni40.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni41.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni42.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni43.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni44.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni45.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni46.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni47.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni48.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni49.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni5.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni50.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni51.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni52.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni53.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni54.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni55.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni56.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni57.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni58.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni59.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni6.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni60.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni61.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni62.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni63.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni64.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni65.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni66.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni67.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni68.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni69.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni7.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni70.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni71.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni72.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni73.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni74.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni75.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni76.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni77.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni78.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni79.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni8.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni80.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni81.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni82.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni83.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni84.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni85.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni86.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni87.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/Dhoni\\Dhoni9.png'],
#  'PV_Sindhu': ['c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu1.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu10.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu100.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu101.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu102.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu103.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu11.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu12.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu13.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu14.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu15.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu16.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu17.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu18.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu19.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu2.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu20.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu21.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu22.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu23.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu24.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu25.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu26.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu27.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu28.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu29.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu3.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu30.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu31.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu32.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu33.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu34.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu35.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu36.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu37.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu38.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu39.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu4.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu40.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu41.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu42.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu43.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu44.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu45.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu46.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu47.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu48.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu49.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu5.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu50.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu51.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu52.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu53.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu54.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu55.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu56.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu57.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu58.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu59.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu6.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu60.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu61.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu62.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu63.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu64.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu65.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu66.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu67.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu68.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu69.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu7.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu70.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu71.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu72.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu73.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu74.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu75.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu76.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu77.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu78.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu79.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu8.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu80.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu81.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu82.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu83.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu84.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu85.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu86.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu87.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu88.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu89.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu9.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu90.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu91.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu92.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu93.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu94.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu95.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu96.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu97.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu98.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/PV_Sindhu\\PV_Sindhu99.png'],
#  'virat': ['c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat1.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat10.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat100.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat101.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat102.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat103.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat104.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat105.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat106.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat107.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat108.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat109.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat11.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat110.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat111.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat112.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat113.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat114.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat115.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat116.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat117.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat118.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat119.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat12.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat120.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat121.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat122.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat123.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat124.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat125.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat126.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat127.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat128.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat129.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat13.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat130.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat131.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat132.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat133.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat134.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat135.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat136.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat137.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat138.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat139.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat14.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat140.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat141.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat142.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat143.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat144.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat145.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat146.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat147.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat148.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat149.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat15.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat150.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat151.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat152.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat153.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat16.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat17.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat18.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat19.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat2.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat20.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat21.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat22.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat23.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat24.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat25.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat26.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat27.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat28.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat29.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat3.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat30.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat31.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat32.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat33.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat34.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat35.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat36.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat37.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat38.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat39.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat4.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat40.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat41.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat42.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat43.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat44.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat45.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat46.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat47.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat48.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat49.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat5.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat50.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat51.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat52.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat53.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat54.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat55.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat56.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat57.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat58.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat59.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat6.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat60.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat61.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat62.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat63.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat64.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat65.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat66.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat67.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat68.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat69.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat7.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat70.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat71.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat72.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat73.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat74.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat75.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat76.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat77.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat78.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat79.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat8.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat80.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat81.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat82.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat83.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat84.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat85.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat86.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat87.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat88.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat89.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat9.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat90.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat91.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat92.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat93.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat94.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat95.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat96.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat97.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat98.png',
#   'c:/users/rahul/work/Sports celebrity classification/Model/dataset/cropped/virat\\virat99.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Dhoni': 0, 'PV_Sindhu': 1, 'virat': 2}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[55],
#        [39],
#        [40],
#        ...,
#        [ 0],
#        [ 0],
#        [ 0]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (343, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8604651162790697

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.76        25
#            1       0.87      0.93      0.90        28
#            2       0.86      0.94      0.90        33
#
#     accuracy                           0.86        86
#    macro avg       0.86      0.85      0.85        86
# weighted avg       0.86      0.86      0.86        86

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.871267
# 1        random_forest    0.739367
# 2  logistic_regression    0.851885
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8488372093023255

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7674418604651163

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8837209302325582

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[16,  5,  4],
#        [ 2, 26,  0],
#        [ 2,  0, 31]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Dhoni': 0, 'PV_Sindhu': 1, 'virat': 2}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\rahul\work\lib\site-packages (1.1.0)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Rahul\work\Scripts\python.exe -m pip install --upgrade pip' command.
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
